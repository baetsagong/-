# %% [markdown]
# <a href="https://colab.research.google.com/github/baetsagong/-/blob/main/9%EB%B2%88%EC%A7%B8%20%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import pandas as pd
from scipy.stats import chi2_contingency

# %%
DATA_DIR = Path('/content/')
file_path = DATA_DIR /'channel_purchase.csv'

# %%
df = pd.read_csv(file_path)

print('[데이터 상위 5행]')
print(df.head(), '\n')

print('[변수 정보]')
print(df.info(), '\n')
# Out:
# [데이터 상위 5행]
#   channel  purchase_yn
# 0    검색광고            1
# 1    검색광고            1
# 2    검색광고            1
# 3    검색광고            1
# 4    검색광고            1
#
# [변수 정보]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   channel      530 non-null    object
#  1   purchase_yn  530 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.4+ KB
# None

# %%
table = pd.crosstab(df['channel'], df['purchase_yn'])

print('[교차표]')
print(table, '\n')
# Out:
# [교차표]
# purchase_yn   0    1
# channel
# SNS          55   70
# 검색광고         50   90
# 이메일          80   45
# 직접방문         30  110

# %%
chi2, p, dof, expected = chi2_contingency(table)

print('[검정 결과]')
print('chi-square statistic:', round(chi2, 4))
print('p-value:', round(p, 6))
print('degrees of freedom:', dof)
# Out:
# [검정 결과]
# chi-square statistic: 51.716
# p-value: 0.0
# degrees of freedom: 3

# %%
expected_df = pd.DataFrame(expected, index=table.index, columns=table.columns)

print('\n[기대도수]')
print(expected_df)
# Out:
# [기대도수]
# purchase_yn          0          1
# channel
# SNS          50.707547  74.292453
# 검색광고         56.792453  83.207547
# 이메일          50.707547  74.292453
# 직접방문         56.792453  83.207547

# %%
conversion_rate = df.groupby('channel')['purchase_yn'].mean().sort_values(ascending=False) * 100

print('\n[채널별 구매전환율(%)]')
print(conversion_rate.round(2))
# Out:
# [채널별 구매전환율(%)]
# channel
# 직접방문    78.57
# 검색광고    64.29
# SNS     56.00
# 이메일     36.00
# Name: purchase_yn, dtype: float64

# %%
from pathlib import Path
import pandas as pd
from scipy.stats import chi2_contingency

# %%
DATA_DIR = Path('/content/')
file_path = DATA_DIR /'gender_preference.csv'

# %%
df = pd.read_csv(file_path)

# 2. 데이터 확인
print('[데이터 상위 5행]')
print(df.head(), '\n')

print('[변수 정보]')
print(df.info(), '\n')
# Out:
# [데이터 상위 5행]
#   gender content_type
# 0     남성        데이터분석
# 1     남성        데이터분석
# 2     남성        데이터분석
# 3     남성        데이터분석
# 4     남성        데이터분석
#
# [변수 정보]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gender        330 non-null    object
#  1   content_type  330 non-null    object
# dtypes: object(2)
# memory usage: 5.3+ KB
# None

# %%
table = pd.crosstab(df['gender'], df['content_type'])

print('[교차표]')
print(table, '\n')
# Out:
# [교차표]
# content_type  데이터분석  디자인  마케팅  프로그래밍
# gender
# 남성               50   18   28     54
# 여성               42   48   55     35

# %%
chi2, p, dof, expected = chi2_contingency(table)

print('[검정 결과]')
print('chi-square statistic:', round(chi2, 4))
print('p-value:', round(p, 6))
print('degrees of freedom:', dof)
# Out:
# [검정 결과]
# chi-square statistic: 24.6478
# p-value: 1.8e-05
# degrees of freedom: 3

# %%
expected_df = pd.DataFrame(expected, index=table.index, columns=table.columns)

print('\n[기대도수]')
print(expected_df)
# Out:
# [기대도수]
# content_type      데이터분석   디자인        마케팅      프로그래밍
# gender
# 남성            41.818182  30.0  37.727273  40.454545
# 여성            50.181818  36.0  45.272727  48.545455

# %%
top_pref = table.idxmax(axis=1)

print('\n[성별별 최다 선호 유형]')
print(top_pref)
# Out:
# [성별별 최다 선호 유형]
# gender
# 남성    프로그래밍
# 여성      마케팅
# dtype: object

# %%
row_ratio = pd.crosstab(df['gender'], df['content_type'], normalize='index') * 100

print('\n[성별 내 콘텐츠 선호 비율(%)]')
print(row_ratio.round(2))
# Out:
# [성별 내 콘텐츠 선호 비율(%)]
# content_type  데이터분석    디자인    마케팅  프로그래밍
# gender
# 남성            33.33  12.00  18.67  36.00
# 여성            23.33  26.67  30.56  19.44
